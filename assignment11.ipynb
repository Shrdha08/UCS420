# %%
#1.

# %% [markdown]
# ![cc122.png](data:image/png;base64,...)

# %% [markdown]
# ![cc12.png](data:image/png;base64,...)

# %%
#2.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
